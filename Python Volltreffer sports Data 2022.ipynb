# %% [markdown]
# # VOLLTREFFER STORE - EDA

# %% [markdown]
# ## Project Overview
# ### Leveraging Python for Actionable Sales Insights in 2022
# This project involves a thorough analysis of Volltreffer Sports' sales data for the year 2022. The primary objective is to utilize Python, specifically libraries such as pandas, seaborn, and matplotlib, to extract insightful information. The aim is to establish a data-driven foundation that can guide informed decision-making processes and ultimately enhance the overall performance and strategic direction of the organization.

# %%
# Import libraries and packages 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data set
data=pd.read_excel('Volltreffer Store Data 2022.xlsx')
data.head()
# Out:
#    Index             Order ID  Cust ID Gender  Age Age Group       Date  \
# 0      1  171-1029312-3038738  1029312  Women   34    Senior 2022-12-04
# 1      2  405-2183842-2225946  2183842  Women   29    Senior 2022-12-04
# 2      3  171-1641533-8921966  1641533  Women   27    Senior 2022-12-04
# 3      4  404-7490807-6300351  7490807  Women   20    Junior 2022-12-04
# 4      5  403-9293516-4577154  9293516  Women   22    Senior 2022-12-04
#
#       Month     Status  Channel                 SKU    Category Size  Qty  \
# 0  December  Delivered  Flipkart       VOLS299-KR-M     T-Shirt  XXL    1
# 1  December  Delivered    Amazon    VOLS30-KR-PP-XS  Sweatshirt    L    1
# 2  December  Delivered  Flipkart    VOLS86-KR-NP-XL  Sweatshirt    S    1
# 3  December  Delivered    Amazon     VOLS65-KR-NP-L  Sweatshirt    M    1
# 4  December  Delivered  Flipkart  VOLS27-KR-DPT-XXL     T-Shirt  XXL    1
#
#   Currency  Amount  Ship-City   Ship-State  Ship-Postal-Code Ship-Country
# 0      INR     376     MOHALI       PUNJAB            140301           IN
# 1      INR     699   GURUGRAM      HARYANA            122002           IN
# 2      INR     453    KOLKATA  WEST BENGAL            700029           IN
# 3      INR     729  THANJAVUR   TAMIL NADU            613007           IN
# 4      INR     544   GURUGRAM      HARYANA            122001           IN

# %% [markdown]
# ## Exploratory Data Analysis (EDA) of Dataset

# %% [markdown]
# Get a sense of how large the dataset is. The size property that DataFrames have can help.

# %%
data.shape
# Out:
# (19999, 20)

# %% [markdown]
# ### Get basic information about the dataset
#
# To further understand what the dataset entails, get basic information about the dataset, including the data type of values in each column. There is more than one way to approach this task. In this instance, use the `info()` function from `pandas`.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19999 entries, 0 to 19998
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Index             19999 non-null  int64
#  1   Order ID          19999 non-null  object
#  2   Cust ID           19999 non-null  int64
#  3   Gender            19999 non-null  object
#  4   Age               19999 non-null  int64
#  5   Age Group         19999 non-null  object
#  6   Date              19999 non-null  datetime64[ns]
#  7   Month             19999 non-null  object
#  8   Status            19999 non-null  object
#  9   Channel           19999 non-null  object
#  10  SKU               19999 non-null  object
#  11  Category          19999 non-null  object
#  12  Size              19999 non-null  object
#  13  Qty               19999 non-null  int64
#  14  Currency          19999 non-null  object
#  15  Amount            19999 non-null  int64
#  16  Ship-City         19999 non-null  object
#  17  Ship-State        19999 non-null  object
#  18  Ship-Postal-Code  19999 non-null  int64
#  19  Ship-Country      19999 non-null  object
# dtypes: datetime64[ns](1), int64(6), object(13)
# memory usage: 3.1+ MB

# %%
data.Amount.describe()
# Out:
# count    19999.000000
# mean       602.359968
# std        159.582000
# min        229.000000
# 25%        487.000000
# 50%        646.000000
# 75%        699.000000
# max        900.000000
# Name: Amount, dtype: float64

# %% [markdown]
# ### Checking for Duplicates

# %%
duplicates=data.duplicated()
print(data[duplicates])
# Out:
# Empty DataFrame
# Columns: [Index, Order ID, Cust ID, Gender, Age, Age Group, Date, Month, Status, Channel , SKU, Category, Size, Qty, Currency, Amount, Ship-City, Ship-State, Ship-Postal-Code, Ship-Country]
# Index: []

# %% [markdown]
# ### Counting Duplicates

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.head()
# Out:
#    Index             Order ID  Cust ID Gender  Age Age Group       Date  \
# 0      1  171-1029312-3038738  1029312  Women   34    Senior 2022-12-04
# 1      2  405-2183842-2225946  2183842  Women   29    Senior 2022-12-04
# 2      3  171-1641533-8921966  1641533  Women   27    Senior 2022-12-04
# 3      4  404-7490807-6300351  7490807  Women   20    Junior 2022-12-04
# 4      5  403-9293516-4577154  9293516  Women   22    Senior 2022-12-04
#
#       Month     Status  Channel                 SKU    Category Size  Qty  \
# 0  December  Delivered  Flipkart       VOLS299-KR-M     T-Shirt  XXL    1
# 1  December  Delivered    Amazon    VOLS30-KR-PP-XS  Sweatshirt    L    1
# 2  December  Delivered  Flipkart    VOLS86-KR-NP-XL  Sweatshirt    S    1
# 3  December  Delivered    Amazon     VOLS65-KR-NP-L  Sweatshirt    M    1
# 4  December  Delivered  Flipkart  VOLS27-KR-DPT-XXL     T-Shirt  XXL    1
#
#   Currency  Amount  Ship-City   Ship-State  Ship-Postal-Code Ship-Country
# 0      INR     376     MOHALI       PUNJAB            140301           IN
# 1      INR     699   GURUGRAM      HARYANA            122002           IN
# 2      INR     453    KOLKATA  WEST BENGAL            700029           IN
# 3      INR     729  THANJAVUR   TAMIL NADU            613007           IN
# 4      INR     544   GURUGRAM      HARYANA            122001           IN

# %%
## Set Index
data.set_index('Index',inplace=True)

# %%
data.head()
# Out:
#                   Order ID  Cust ID Gender  Age Age Group       Date  \
# Index
# 1      171-1029312-3038738  1029312  Women   34    Senior 2022-12-04
# 2      405-2183842-2225946  2183842  Women   29    Senior 2022-12-04
# 3      171-1641533-8921966  1641533  Women   27    Senior 2022-12-04
# 4      404-7490807-6300351  7490807  Women   20    Junior 2022-12-04
# 5      403-9293516-4577154  9293516  Women   22    Senior 2022-12-04
#
#           Month     Status  Channel                 SKU    Category Size  Qty  \
# Index
# 1      December  Delivered  Flipkart       VOLS299-KR-M     T-Shirt  XXL    1
# 2      December  Delivered    Amazon    VOLS30-KR-PP-XS  Sweatshirt    L    1
# 3      December  Delivered  Flipkart    VOLS86-KR-NP-XL  Sweatshirt    S    1
# 4      December  Delivered    Amazon     VOLS65-KR-NP-L  Sweatshirt    M    1
# 5      December  Delivered  Flipkart  VOLS27-KR-DPT-XXL     T-Shirt  XXL    1
#
#       Currency  Amount  Ship-City   Ship-State  Ship-Postal-Code Ship-Country
# Index
# 1          INR     376     MOHALI       PUNJAB            140301           IN
# 2          INR     699   GURUGRAM      HARYANA            122002           IN
# 3          INR     453    KOLKATA  WEST BENGAL            700029           IN
# 4          INR     729  THANJAVUR   TAMIL NADU            613007           IN
# 5          INR     544   GURUGRAM      HARYANA            122001           IN

# %%
data.columns
# Out:
# Index(['Order ID', 'Cust ID', 'Gender', 'Age', 'Age Group', 'Date', 'Month',
#        'Status', 'Channel ', 'SKU', 'Category', 'Size', 'Qty', 'Currency',
#        'Amount', 'Ship-City', 'Ship-State', 'Ship-Postal-Code',
#        'Ship-Country'],
#       dtype='object')

# %%
grouped_by_category = data.groupby('Category')['Amount'].sum()
grouped_by_category.sort_values(ascending=False)
# Out:
# Category
# Sweatshirt    5914823
# T-Shirt       2975256
# Activwear     1697879
# Topwear       1317097
# Gymvest        123811
# Bottomwear      17731
# Name: Amount, dtype: int64

# %%
# Calculate total sales by month
total_sales_by_month = data.groupby('Month')['Amount'].sum().sort_values(ascending=False).reset_index()

# Create a line chart
plt.figure(figsize=(10, 6))
sns.lineplot(x='Month', y='Amount', data=total_sales_by_month, marker='o', color='red')
plt.title('Total Sales Trend by Month')
plt.xlabel('Month')
plt.ylabel('Total Amount in Million')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.grid(True)  # Add grid for better visualization
plt.show()

# %% [markdown]
# #### The analysis reveals that March was the best-performing month in terms of sales, with a total revenue of 1,29,651.  This insight is crucial for resource allocation and strategic planning.

# %%
total_sales_by_month = data.groupby('Month')['Amount'].sum().sort_values(ascending=False).reset_index()


plt.figure(figsize=(10, 6))
sns.barplot(x='Month', y='Amount', data=total_sales_by_month,palette='viridis')
plt.title('Total Sales by Month')
plt.xlabel('Month')
plt.ylabel('Total Amount in Million')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
# Group by 'City' and calculate the sum of 'Amount'
city_sales = data.groupby('Ship-State')['Amount'].sum().sort_values(ascending=False)

# Select the top 10 performing cities
top_10_cities = city_sales.head(10)

# Create a new DataFrame with the results
result_df = pd.DataFrame({
    'Ship-State': top_10_cities.index,
    'Amount': top_10_cities.values
})

# Visualize the results using Seaborn
plt.figure(figsize=(12, 6))
sns.barplot(x='Ship-State', y='Amount', data=result_df, palette='viridis')
plt.title('Top 10 Performing State - Sales Analysis')
plt.xlabel('State')
plt.ylabel('Total Sales Amount in Million')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# #### Maharashtra emerged as the top-selling State, indicating a significant market presence. Understanding State-wise sales patterns can aid in targeted marketing and inventory management.

# %%
# Group by 'City' and calculate the sum of 'Amount'
city_sales = data.groupby('Ship-City')['Amount'].sum().sort_values(ascending=False)

# Select the top 10 performing cities
top_10_cities = city_sales.head(10)

# Create a new DataFrame with the results
result_df = pd.DataFrame({
    'Ship-City': top_10_cities.index,
    'Amount': top_10_cities.values
})

# Visualize the results using Seaborn
plt.figure(figsize=(12, 6))
sns.barplot(x='Ship-City', y='Amount', data=result_df)
plt.title('Top 10 Performing Cities - Sales Analysis')
plt.xlabel('City')
plt.ylabel('Total Sales Amount in Million')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
total_sales_by_category = data.groupby('Category')['Amount'].sum().sort_values(ascending=False).reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Amount', data=total_sales_by_category)
plt.title('Total Sales by Category')
plt.xlabel('Category')
plt.ylabel('Total Amount in Million')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
total_sales_by_gender = data.groupby('Gender')['Amount'].sum().reset_index()

plt.figure(figsize=(10, 6))

# Plotting a pie chart
plt.pie(total_sales_by_gender['Amount'], labels=total_sales_by_gender['Gender'], autopct='%1.1f%%', startangle=90)

plt.title('Total Sales by Gender')
plt.show()

# %%
# Subset the data for women's and men's items
women_items = data[data['Gender'] == 'Women']
men_items = data[data['Gender'] == 'Men']

# Analyze the most popular women's items
women_popular_items = women_items.groupby('Category')['Amount'].sum().sort_values(ascending=False).head(5)

# Analyze the most popular men's items
men_popular_items = men_items.groupby('Category')['Amount'].sum().sort_values(ascending=False).head(5)


plt.figure(figsize=(14, 8))
# Women's items plot
plt.subplot(2, 2, 1)
sns.barplot(x=women_popular_items.index, y=women_popular_items.values, palette='viridis')
plt.title("Women's Most Popular Items")
plt.xlabel('Product Category')
plt.ylabel('Total Amount in Million')

# Men's items plot
plt.subplot(2, 2, 2)
sns.barplot(x=men_popular_items.index, y=men_popular_items.values, palette='viridis')
plt.title("Men's Most Popular Items")
plt.xlabel('Product Category')
plt.ylabel('Total Amount in Million')

plt.tight_layout()
plt.show()

# %%
total_sales_by_size = data.groupby('Size')['Amount'].sum().sort_values(ascending=False).reset_index()


plt.figure(figsize=(10, 6))
sns.barplot(x='Size', y='Amount', data=total_sales_by_size,)
plt.title('Total Sales by Size')
plt.xlabel('Size')
plt.ylabel('Total Amount in Million')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
total_sales_by_channel = data.groupby('Channel ')['Amount'].sum().reset_index()

plt.figure(figsize=(10, 6))

# Plotting a pie chart
plt.pie(total_sales_by_channel ['Amount'], labels=total_sales_by_channel ['Channel '], autopct='%1.1f%%', startangle=90)

plt.title('Total Sales by Channel')
plt.show()

# %%
total_sales_by_status = data.groupby('Status')['Amount'].count().sort_values(ascending=False).reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='Status', y='Amount', data=total_sales_by_status,palette='viridis')
plt.title('Total Sales by Status')
plt.xlabel('Status')
plt.ylabel('Total Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()
